# %%
# how to remove duplicate elements
l=[9,0,67,0,8,8]
set(l)
# Out:
# {0, 8, 9, 67}

# %%
s={89,90,6,'p',788888888,456,9,8,88}
s
# Out:
# {456, 6, 788888888, 8, 88, 89, 9, 90, 'p'}

# %%
s={89,90,6,'p',788888888,456,9,(8,88)}
s
# Out:
# {(8, 88), 456, 6, 788888888, 89, 9, 90, 'p'}

# %%
s=[89,90,6,'p',788888888,456,9,8,88]
s

# %%
s={89,90,6,'p',788888888,456,9,8,88}
s[0]=9
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 s={89,90,6,'p',788888888,456,9,8,88}
# ----> 2 s[0]=9
#
# TypeError: 'set' object does not support item assignment

# %%
s={9,9,0}
s.add(7)
s
# Out:
# {0, 7, 9}

# %%
s={9,9,0}
s.update([7,0,9])
s
# Out:
# {0, 7, 9}

# %%
s={9,9,0}
s.add((8,6,7))
s
# Out:
# {(8, 6, 7), 0, 9}

# %%
s={9,9,0}
s.add((8,8,0))
s
# Out:
# {(8, 8, 0), 0, 9}

# %%
# i want to delete value
s={5,8,9}
s.remove(9)
s
# Out:
# {5, 8}

# %%
s={5,8,9}
s.discard(9)
s
# Out:
# {5, 8}

# %%
s={5,8,9}
s.discard(4)
s
# Out:
# {5, 8, 9}

# %%
# i want to delete value
s={5,8,9}
s.remove(4)
s
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 3
#       1 # i want to delete value
#       2 s={5,8,9}
# ----> 3 s.remove(4)
#       4 s
#
# KeyError: 4

# %%
s={5,8,9}
s.pop()
s
# Out:
# {5, 9}

# %%
l=[4,5,26,8,3]
l.pop()
l
# Out:
# [4, 5, 26, 8]

# %%
l=[4,5,26,8,3]
l.pop(0)
l
# Out:
# [5, 26, 8, 3]
